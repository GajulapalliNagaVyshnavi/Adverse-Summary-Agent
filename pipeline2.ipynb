# %%
import pandas as pd
import os
from openai import OpenAI
import plotly.express as px
from IPython.display import display, HTML
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = OpenAI(
	api_key=os.getenv("OPENAI_API_KEY"),
)

# %%
def load_data(file_path):
    return pd.read_csv(file_path)

# %%
def preprocess_data(df):
    # Remove any empty rows or columns
    df = df.dropna(how='all').dropna(axis=1, how='all')
    return df

# %%
def generate_summary(data):
    prompt = f"""
    *Prompt 1: Section Brief Summary of Adverse Events*
    You will be given tables in the variable 'input tables' which includes information about brief summary of adverse events that occurred during a clinical trial. Identify the data according to the instructions. You will be given the necessary context to answer certain questions. Avoid fabricating responses. Do not elaborate.
    Context: Given the following data from a clinical trial, summarize the key information about the total number of subjects with Treatment Emergent Adverse Event(TEAE) and Serious Adverse Events(SAE).
    Below are multiple table details. For each table you are given the table title, i.e., "table title: " which tells what information is in the table, and the table itself, i.e. "table: ". With the table title and table content, follow the below task.
    Task: Summarize the table title and then provide the table reference (you will find in this format x.x.x.x. where x is integer). An example of how to begin the summary: A summary of treatment related adverse events (TEAE) is provided in table 14.2.1
    Summarize the results for each cohort of the population in the clinical trial in separate paragraphs. Cohorts may include treatment arms, phases, parts, cohorts, periods and other categories (e.g., in the drug xx treatment arm 3 subjects experienced a treatment-emergent adverse event). The summary should be about AEs or SARs or TEAEs.

    Input tables:

    {data.to_string()}

    Please provide a summary based on the above instructions and data.
    """

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a clinical trial data analyst specializing in summarizing adverse event data."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=1000
    )

    return response.choices[0].message.content

# %%
file_path = 'Brief Summary of Adverse Events.csv'
df = load_data(file_path)
processed_df = preprocess_data(df)

# %%
print("Processed Data:")
display(processed_df)
# Out:
# Processed Data:
#                                           Unnamed: 0    Vehicle      0.10%  \
# 0                                                NaN         QD         QD
# 1                             Number (%) of subjects      n (%)      n (%)
# 2              Subjects evaluable for adverse events         39         39
# 3                           Number of adverse events         28         24
# 4                       Subjects with adverse events  18 (46.2)  17 (43.6)
# 5                Subjects with severe adverse events          0          0
# 6  Subject discontinued from study due to adverse...    3 (7.7)    2 (5.1)
# 7  Subjects discontinued study drug due to AE and...          0    2 (5.1)
# 8  Subjects with temporary discontinuation due to...    3 (7.7)    1 (2.6)
#
#        0.50%      1.00%      5.00%  Vehicle.1    0.50%.1    1.00%.1  \
# 0         QD         QD         QD        TID        TID        TID
# 1      n (%)      n (%)      n (%)      n (%)      n (%)      n (%)
# 2         36         39         36         36         36         39
# 3         19         23         13         27         13         19
# 4  11 (30.6)  12 (30.8)  10 (27.8)  17 (47.2)  9 (25.0)   14 (35.9)
# 5          0          0          0    1 (2.8)    1 (2.8)          0
# 6    1 (2.8)    2 (5.1)    2 (5.6)   5 (13.9)    1 (2.8)          0
# 7          0          0          0    1 (2.8)          0          0
# 8          0          0    1 (2.8)          0          0          0
#
#         Total
# 0         NaN
# 1       n (%)
# 2         300
# 3         166
# 4  108 (36.0)
# 5     2 (0.7)
# 6    16 (3.9)
# 7     3 (1.0)
# 8     5 (1.8)

# %%
#####gpt-4o-mini
generated_summary = generate_summary(processed_df)
print("\nGenerated Summary:")
print(generated_summary)
# Out:
# Generated Summary:
# A summary of treatment emergent adverse events (TEAE) is provided in table 14.2.1.
#
# In the Vehicle cohort, out of 39 evaluable subjects, 18 (46.2%) experienced adverse events. There were no severe adverse events reported and 3 subjects discontinued the study due to adverse events.
#
# In the 0.10% treatment arm, also with 39 evaluable subjects, 17 (43.6%) reported adverse events. Similar to the Vehicle cohort, there were no severe adverse events, but 2 subjects discontinued the study due to adverse events.
#
# In the 0.50% treatment arm, 36 subjects were evaluable and 11 (30.6%) had adverse events; there were no severe adverse events, and 1 subject discontinued due to adverse events.
#
# In the 1.00% treatment arm, 39 subjects were evaluable with 12 (30.8%) experiencing adverse events, and again no severe adverse events were reported. A total of 2 subjects discontinued the study due to adverse events.
#
# In the 5.00% treatment arm, 36 evaluable subjects had 10 (27.8%) report adverse events, with no severe adverse events, and 2 subjects discontinuing the study due to adverse events.
#
# In the Vehicle.1 cohort consisting of 36 evaluable subjects, 17 (47.2%) experienced adverse events. There was 1 (2.8%) reported severe adverse event and 5 subjects discontinued the study due to adverse events.
#
# For the 0.50%.1 treatment arm, 36 subjects were evaluable with 9 (25.0%) reporting adverse events. There were 1 (2.8%) severe adverse event and 1 subject discontinued due to adverse events.
#
# In the 1.00%.1 treatment arm, 39 evaluable subjects saw 14 (35.9%) report adverse events. No severe adverse events occurred, and there were no discontinuations due to adverse events.
#
# Overall, a total of 108 out of 300 evaluable subjects experienced treatment emergent adverse events, with 2 (0.7%) subjects having severe adverse events and a total of 16 (3.9%) subjects discontinuing the study due to adverse events.

# %%
#####gpt4
summary = generate_summary(processed_df)
print("\nGenerated Summary:")
print(summary)
